# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv('FinalData.csv')
df1
# Out:
#     YEAR  Gross_Weight_Of\n_Goods_Handled\n(in thousand tonnes)  \
# 0   2010                                            3034880
# 1   2011                                            3094060
# 2   2012                                            3154395
# 3   2013                                            3215906
# 4   2014                                            3287210
# 5   2015                                            3343755
# 6   2016                                            3376704
# 7   2017                                            3476076
# 8   2018                                            3584537
# 9   2019                                            3587258
# 10  2020                                            3325646
#
#     Volume(inTEUs)_of_\ncontainers_handled  \
# 0                                    53317
# 1                                    63981
# 2                                    76778
# 3                                    78314
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
X = df1.drop('Gross_Value_Added \n(in Thousand Euros)\nin Marinetime_transport_sector', axis=1)  
#X = X.drop('Turnover(in thousand euros)\nin Marinetime_transport_sector', axis=1)

#X = X.drop('YEAR', axis=1)
#X = X.drop('Gross_Weight_Of\n_Goods_Handled\n(in thousand tonnes)', axis=1)
X = X.drop('Volume(inTEUs)_of_\ncontainers_handled', axis=1)
#X = X.drop('Pasangers_embarked_and_disembarkes\n(in_thousands)', axis=1)
#X = X.drop('Pasangers_inward\n(in thousands)', axis=1)
#X = X.drop('Pasangers_outward\n(in thousands)', axis=1)
#X = X.drop('ShortSeaShipping_Weight\n_of_Goods_transported\n(in thousands tonnes)', axis=1)
#X = X.drop('DeepSeaShipping_Weight_\nof_Goods_transported\n(in thousand tonnes)', axis=1)
#X = X.drop('Marinetime_goods_transport_performed\n(inExclusiveEconomicZoneofthecountry\n(inMillionTonne-kilometer))', axis=1)
#X = X.drop('Total_Vessels', axis=1)

#X = X.drop('Other_Vessels\nJ-K-L', axis=1)
#X = X.drop('Container_Ship\nVessel', axis=1)
#X = X.drop('Liquid_Bulk_Tanker\nVessel', axis=1)
#X = X.drop('Pasanger_Ship\nVessel', axis=1)
#X = X.drop('GeneralCargo(NonSpecialised)\nvessel', axis=1)


#X = X.drop('Gross_tonnage_in_thousands_by_all types_of_\nvessels\n', axis=1)
Y = df1['Gross_Value_Added \n(in Thousand Euros)\nin Marinetime_transport_sector']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# %%
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = model.predict(X_test)
Y_pred
# Out:
# array([26825.27272022, 33285.87578181, 28660.82991459])

# %%
Y_test
# Out:
# 4    28785
# 9    34244
# 5    32476
# Name: Gross_Value_Added \n(in Thousand Euros)\nin Marinetime_transport_sector, dtype: int64

# %%
X_test
# Out:
#    YEAR  Gross_Weight_Of\n_Goods_Handled\n(in thousand tonnes)  \
# 4  2014                                            3287210
# 9  2019                                            3587258
# 5  2015                                            3343755
#
#    Pasangers_embarked_and_disembarkes\n(in_thousands)  \
# 4                                             365240
# 9                                             418488
# 5                                             368222
#
#    Pasangers_inward\n(in thousands)  Pasangers_outward\n(in thousands)  \
# 4                            182617                             182086
# 9                            208739                             208265
# 5                            184268                             183111
#
#    ShortSeaShipping_Weight\n_of_Goods_transported\n(in thousands tonnes)  \
# 4                                            1638403
# 9                                            1800469
# ...

# %%
model.score(X_test,Y_test)
# Out:
# -0.24473007205064734

# %%
mse = mean_squared_error(Y_test, Y_pred)
print('Mean Squared Error:', mse)
# Out:
# Mean Squared Error: 6438018.603081848

# %%
from sklearn.model_selection import cross_val_score
cv_scores = cross_val_score(model, X_train, Y_train, cv=3)
print('Cross-Validation Scores:', cv_scores)
# Out:
# Cross-Validation Scores: [ -1.71417177 -15.98272654  -8.7442594 ]

# %%
coefficients = pd.DataFrame({'Feature': X.columns, 'Coefficient': model.coef_})
coefficients['Absolute_Coefficient'] = coefficients['Coefficient'].abs()
coefficients = coefficients.sort_values(by='Absolute_Coefficient', ascending=False)
print(coefficients)
# Out:
#                                               Feature   Coefficient  \
# 1   Gross_Weight_Of\n_Goods_Handled\n(in thousand ... -4.572310e-02
# 7   Marinetime_goods_transport_performed\n(inExclu...  4.061187e-02
# 2   Pasangers_embarked_and_disembarkes\n(in_thousa...  3.961053e-02
# 4                   Pasangers_outward\n(in thousands)  2.040129e-02
# 12                             Container_Ship\nVessel  1.857850e-02
# 3                    Pasangers_inward\n(in thousands)  1.839226e-02
# 9                GeneralCargo(NonSpecialised)\nvessel -1.640505e-02
# 15  Turnover(in thousand euros)\nin Marinetime_tra... -1.504884e-02
# 10                              Pasanger_Ship\nVessel -1.491093e-02
# 13                               Other_Vessels\nJ-K-L  1.265214e-02
# 6   DeepSeaShipping_Weight_\nof_Goods_transported\... -8.641983e-03
# 11                         Liquid_Bulk_Tanker\nVessel  3.906261e-03
# 8                                       Total_Vessels  3.820925e-03
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.scatter(X['YEAR'], Y, color='blue', label='Data')

# %%
plt.plot(X['YEAR'], Y, color='red', linewidth=2, label='Linear Regression')
plt.xlabel('YEAR')
plt.ylabel('Target')
plt.title('Linear Regression')
plt.legend()
plt.show()

# %%
plt.scatter(X['Gross_Weight_Of\n_Goods_Handled\n(in thousand tonnes)'], Y, color='blue', label='Data')

# %%
plt.plot(X['Gross_Weight_Of\n_Goods_Handled\n(in thousand tonnes)'], Y, color='red', linewidth=2, label='Linear Regression')
plt.xlabel('Gross_Weight_Of\n_Goods_Handled\n(in thousand tonnes)')
plt.ylabel('Target')
plt.title('Linear Regression')
plt.legend()
plt.show()

# %%
plt.plot(X['Pasangers_embarked_and_disembarkes\n(in_thousands)'], Y, color='red', linewidth=2, label='Linear Regression')
plt.xlabel('Pasangers_embarked_and_disembarkes\n(in_thousands)')
plt.ylabel('Target')
plt.title('Linear Regression')
plt.legend()
plt.show()

# %%
plt.plot(X['Pasangers_inward\n(in thousands)'], Y, color='red', linewidth=2, label='Linear Regression')
plt.xlabel('Pasangers_inward\n(in thousands)')
plt.ylabel('Target')
plt.title('Linear Regression')
plt.legend()
plt.show()

# %%
plt.plot(X['Pasangers_outward\n(in thousands)'], Y, color='red', linewidth=2, label='Linear Regression')
plt.xlabel('Pasangers_outward\n(in thousands)')
plt.ylabel('Target')
plt.title('Linear Regression')
plt.legend()
plt.show()

# %%
plt.plot(X['ShortSeaShipping_Weight\n_of_Goods_transported\n(in thousands tonnes)'], Y, color='red', linewidth=2, label='Linear Regression')
plt.xlabel('ShortSeaShipping_Weight\n_of_Goods_transported\n(in thousands tonnes)')
plt.ylabel('Target')
plt.title('Linear Regression')
plt.legend()
plt.show()

# %%
plt.plot(X['DeepSeaShipping_Weight_\nof_Goods_transported\n(in thousand tonnes)'], Y, color='red', linewidth=2, label='Linear Regression')
plt.xlabel('DeepSeaShipping_Weight_\nof_Goods_transported\n(in thousand tonnes)')
plt.ylabel('Target')
plt.title('Linear Regression')
plt.legend()
plt.show()

# %%
plt.plot(X['Marinetime_goods_transport_performed\n(inExclusiveEconomicZoneofthecountry\n(inMillionTonne-kilometer))'], Y, color='red', linewidth=2, label='Linear Regression')
plt.xlabel('Marinetime_goods_transport_performed\n(inExclusiveEconomicZoneofthecountry\n(inMillionTonne-kilometer))')
plt.ylabel('Target')
plt.title('Linear Regression')
plt.legend()
plt.show()

# %%
plt.plot(X['Total_Vessels'], Y, color='red', linewidth=2, label='Linear Regression')
plt.xlabel('Total_Vessels')
plt.ylabel('Target')
plt.title('Linear Regression')
plt.legend()
plt.show()

# %%
plt.plot(X['GeneralCargo(NonSpecialised)\nvessel'], Y, color='red', linewidth=2, label='Linear Regression')
plt.xlabel('GeneralCargo(NonSpecialised)\nvessel')
plt.ylabel('Target')
plt.title('Linear Regression')
plt.legend()
plt.show()

# %%
plt.plot(X['Pasanger_Ship\nVessel'], Y, color='red', linewidth=2, label='Linear Regression')
plt.xlabel('Pasanger_Ship\nVessel')
plt.ylabel('Target')
plt.title('Linear Regression')
plt.legend()
plt.show()

# %%
plt.plot(X['Liquid_Bulk_Tanker\nVessel'], Y, color='red', linewidth=2, label='Linear Regression')
plt.xlabel('Liquid_Bulk_Tanker\nVessel')
plt.ylabel('Target')
plt.title('Linear Regression')
plt.legend()
plt.show()

# %%
plt.plot(X['Container_Ship\nVessel'], Y, color='red', linewidth=2, label='Linear Regression')
plt.xlabel('Container_Ship\nVessel')
plt.ylabel('Target')
plt.title('Linear Regression')
plt.legend()
plt.show()

# %%
plt.plot(X['Other_Vessels\nJ-K-L'], Y, color='red', linewidth=2, label='Linear Regression')
plt.xlabel('Other_Vessels\nJ-K-L')
plt.ylabel('Target')
plt.title('Linear Regression')
plt.legend()
plt.show()

# %%
plt.plot(X['Turnover(in thousand euros)\nin Marinetime_transport_sector'], Y, color='red', linewidth=2, label='Linear Regression')
plt.xlabel('Turnover(in thousand euros)\nin Marinetime_transport_sector')
plt.ylabel('Target')
plt.title('Linear Regression')
plt.legend()
plt.show()
