# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv('FinalData.csv')
df1=df1[0:11]
df1
# Out:
#       YEAR  Gross_Weight_Of\n_Goods_Handled\n(in thousand tonnes)  \
# 0   2010.0                                          3034880.0
# 1   2011.0                                          3094060.0
# 2   2012.0                                          3154395.0
# 3   2013.0                                          3215906.0
# 4   2014.0                                          3287210.0
# 5   2015.0                                          3343755.0
# 6   2016.0                                          3376704.0
# 7   2017.0                                          3476076.0
# 8   2018.0                                          3584537.0
# 9   2019.0                                          3587258.0
# 10  2020.0                                          3325646.0
#
#     Volume(inTEUs)_of_\ncontainers_handled  \
# 0                                  53317.0
# 1                                  63981.0
# 2                                  76778.0
# 3                                  78314.0
# 4                                  82884.0
# 5                                  82206.0
# 6                                  86539.0
# 7                                  89692.0
# 8                                  96798.0
# 9                                  96573.0
# 10                                 94297.0
#
#     Pasangers_embarked_and_disembarkes\n(in_thousands)  \
# 0                                            396348.0
# 1                                            384800.0
# 2                                            371689.0
# 3                                            372732.0
# 4                                            365240.0
# 5                                            368222.0
# 6                                            370467.0
# 7                                            389537.0
# 8                                            411006.0
# 9                                            418488.0
# 10                                           230121.0
#
#     Pasangers_inward\n(in thousands)  Pasangers_outward\n(in thousands)  \
# 0                           198934.0                           197414.0
# 1                           192466.0                           192334.0
# 2                           186219.0                           185470.0
# 3                           186250.0                           186028.0
# 4                           182617.0                           182086.0
# 5                           184268.0                           183111.0
# 6                           185274.0                           184105.0
# 7                           194779.0                           193390.0
# 8                           205451.0                           204047.0
# 9                           208739.0                           208265.0
# 10                          115115.0                           114599.0
#
#     ShortSeaShipping_Weight\n_of_Goods_transported\n(in thousands tonnes)  \
# 0                                           1618837.0
# 1                                           1636150.0
# 2                                           1614816.0
# 3                                           1610880.0
# 4                                           1638403.0
# 5                                           1660535.0
# 6                                           1702834.0
# 7                                           1711477.0
# 8                                           1771398.0
# 9                                           1800469.0
# 10                                          1682005.0
#
#     DeepSeaShipping_Weight_\nof_Goods_transported\n(in thousand tonnes)  \
# 0                                            946958.0
# 1                                           1023042.0
# 2                                           1034662.0
# 3                                           1032035.0
# 4                                           1053376.0
# 5                                           1063441.0
# 6                                           1040279.0
# 7                                           1096029.0
# 8                                           1137964.0
# 9                                           1169011.0
# 10                                          1067160.0
#
#     Marinetime_goods_transport_performed\n(inExclusiveEconomicZoneofthecountry\n(inMillionTonne-kilometer))  \
# 0                                           4448441.0
# 1                                           4525844.0
# 2                                           4604594.0
# 3                                           4684714.0
# 4                                           4746385.0
# 5                                           4850032.0
# 6                                           4842221.0
# 7                                           5059154.0
# 8                                           5207869.0
# 9                                           5317875.0
# 10                                          5036425.0
#
#     Total_Vessels  GeneralCargo(NonSpecialised)\nvessel  \
# 0       2134012.0                             1191665.0
# 1       2181926.0                             1604546.0
# 2       2096398.0                             1536204.0
# 3       2016989.0                             1480749.0
# 4       2068414.0                             1522402.0
# 5       1991274.0                             1430425.0
# 6       1989123.0                             1403199.0
# 7       2026259.0                             1440847.0
# 8       2189422.0                             1583477.0
# 9       2278469.0                             1649665.0
# 10      1944030.0                             1503487.0
#
#     Pasanger_Ship\nVessel  Liquid_Bulk_Tanker\nVessel  Container_Ship\nVessel  \
# 0                650397.0                     94503.0                 91115.0
# 1                301284.0                     92285.0                 78854.0
# 2                296129.0                     90547.0                 70608.0
# 3                275622.0                     88853.0                 69448.0
# 4                292222.0                     85499.0                 66440.0
# 5                314502.0                     82067.0                 72050.0
# 6                328386.0                     81883.0                 75510.0
# 7                319711.0                     83334.0                 75640.0
# 8                340848.0                     83909.0                 75639.0
# 9                363473.0                     86846.0                 71518.0
# 10               215768.0                     81079.0                 66720.0
#
#     Other_Vessels\nJ-K-L  \
# 0               106332.0
# 1               104957.0
# 2               102910.0
# 3               102317.0
# 4               101851.0
# 5                92230.0
# 6               100145.0
# 7               106727.0
# 8               105549.0
# 9               106967.0
# 10               76976.0
#
#     Gross_tonnage_in_thousands_by_all types_of_\nvessels\n  \
# 0                                          13739816.0
# 1                                          14077937.0
# 2                                          13905003.0
# 3                                          13711175.0
# 4                                          13679852.0
# 5                                          14280662.0
# 6                                          14911085.0
# 7                                          15447891.0
# 8                                          16173588.0
# 9                                          16288379.0
# 10                                         13250266.0
#
#     Gross_Value_Added \n(in Thousand Euros)\nin Marinetime_transport_sector  \
# 0                                             30004.0
# 1                                             27108.0
# 2                                             27419.0
# 3                                             29049.0
# 4                                             28785.0
# 5                                             32476.0
# 6                                             27088.0
# 7                                             31032.0
# 8                                             30123.0
# 9                                             34244.0
# 10                                            29509.0
#
#     Turnover(in thousand euros)\nin Marinetime_transport_sector
# 0                                            134200.0
# 1                                            136167.0
# 2                                            145742.0
# 3                                            141348.0
# 4                                            139612.0
# 5                                            150563.0
# 6                                            139315.0
# 7                                            155320.0
# 8                                            160310.0
# 9                                            163249.0
# 10                                           147421.0

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import mean_squared_error

# %%
X = df1.drop('Gross_Value_Added \n(in Thousand Euros)\nin Marinetime_transport_sector', axis=1)  
#X = X.drop('Turnover(in thousand euros)\nin Marinetime_transport_sector', axis=1)

#X = X.drop('YEAR', axis=1)
#X = X.drop('Gross_Weight_Of\n_Goods_Handled\n(in thousand tonnes)', axis=1)
X = X.drop('Volume(inTEUs)_of_\ncontainers_handled', axis=1)
#X = X.drop('Pasangers_embarked_and_disembarkes\n(in_thousands)', axis=1)
#X = X.drop('Pasangers_inward\n(in thousands)', axis=1)
#X = X.drop('Pasangers_outward\n(in thousands)', axis=1)
#X = X.drop('ShortSeaShipping_Weight\n_of_Goods_transported\n(in thousands tonnes)', axis=1)
#X = X.drop('DeepSeaShipping_Weight_\nof_Goods_transported\n(in thousand tonnes)', axis=1)
#X = X.drop('Marinetime_goods_transport_performed\n(inExclusiveEconomicZoneofthecountry\n(inMillionTonne-kilometer))', axis=1)
#X = X.drop('Total_Vessels', axis=1)

#X = X.drop('Other_Vessels\nJ-K-L', axis=1)
#X = X.drop('Container_Ship\nVessel', axis=1)
#X = X.drop('Liquid_Bulk_Tanker\nVessel', axis=1)
#X = X.drop('Pasanger_Ship\nVessel', axis=1)
#X = X.drop('GeneralCargo(NonSpecialised)\nvessel', axis=1)


#X = X.drop('Gross_tonnage_in_thousands_by_all types_of_\nvessels\n', axis=1)
Y = df1['Gross_Value_Added \n(in Thousand Euros)\nin Marinetime_transport_sector']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.1)

# %%
X_train
# Out:
#       YEAR  Gross_Weight_Of\n_Goods_Handled\n(in thousand tonnes)  \
# 9   2019.0                                          3587258.0
# 0   2010.0                                          3034880.0
# 4   2014.0                                          3287210.0
# 3   2013.0                                          3215906.0
# 10  2020.0                                          3325646.0
# 1   2011.0                                          3094060.0
# 6   2016.0                                          3376704.0
# 2   2012.0                                          3154395.0
# 7   2017.0                                          3476076.0
#
#     Pasangers_embarked_and_disembarkes\n(in_thousands)  \
# 9                                            418488.0
# 0                                            396348.0
# 4                                            365240.0
# 3                                            372732.0
# 10                                           230121.0
# 1                                            384800.0
# 6                                            370467.0
# 2                                            371689.0
# 7                                            389537.0
#
#     Pasangers_inward\n(in thousands)  Pasangers_outward\n(in thousands)  \
# 9                           208739.0                           208265.0
# 0                           198934.0                           197414.0
# 4                           182617.0                           182086.0
# 3                           186250.0                           186028.0
# 10                          115115.0                           114599.0
# 1                           192466.0                           192334.0
# 6                           185274.0                           184105.0
# 2                           186219.0                           185470.0
# 7                           194779.0                           193390.0
#
#     ShortSeaShipping_Weight\n_of_Goods_transported\n(in thousands tonnes)  \
# 9                                           1800469.0
# 0                                           1618837.0
# 4                                           1638403.0
# 3                                           1610880.0
# 10                                          1682005.0
# 1                                           1636150.0
# 6                                           1702834.0
# 2                                           1614816.0
# 7                                           1711477.0
#
#     DeepSeaShipping_Weight_\nof_Goods_transported\n(in thousand tonnes)  \
# 9                                           1169011.0
# 0                                            946958.0
# 4                                           1053376.0
# 3                                           1032035.0
# 10                                          1067160.0
# 1                                           1023042.0
# 6                                           1040279.0
# 2                                           1034662.0
# 7                                           1096029.0
#
#     Total_Vessels  GeneralCargo(NonSpecialised)\nvessel  \
# 9       2278469.0                             1649665.0
# 0       2134012.0                             1191665.0
# 4       2068414.0                             1522402.0
# 3       2016989.0                             1480749.0
# 10      1944030.0                             1503487.0
# 1       2181926.0                             1604546.0
# 6       1989123.0                             1403199.0
# 2       2096398.0                             1536204.0
# 7       2026259.0                             1440847.0
#
#     Pasanger_Ship\nVessel  Liquid_Bulk_Tanker\nVessel  Container_Ship\nVessel  \
# 9                363473.0                     86846.0                 71518.0
# 0                650397.0                     94503.0                 91115.0
# 4                292222.0                     85499.0                 66440.0
# 3                275622.0                     88853.0                 69448.0
# 10               215768.0                     81079.0                 66720.0
# 1                301284.0                     92285.0                 78854.0
# 6                328386.0                     81883.0                 75510.0
# 2                296129.0                     90547.0                 70608.0
# 7                319711.0                     83334.0                 75640.0
#
#     Other_Vessels\nJ-K-L  \
# 9               106967.0
# 0               106332.0
# 4               101851.0
# 3               102317.0
# 10               76976.0
# 1               104957.0
# 6               100145.0
# 2               102910.0
# 7               106727.0
#
#     Gross_tonnage_in_thousands_by_all types_of_\nvessels\n  \
# 9                                          16288379.0
# 0                                          13739816.0
# 4                                          13679852.0
# 3                                          13711175.0
# 10                                         13250266.0
# 1                                          14077937.0
# 6                                          14911085.0
# 2                                          13905003.0
# 7                                          15447891.0
#
#     Turnover(in thousand euros)\nin Marinetime_transport_sector
# 9                                            163249.0
# 0                                            134200.0
# 4                                            139612.0
# 3                                            141348.0
# 10                                           147421.0
# 1                                            136167.0
# 6                                            139315.0
# 2                                            145742.0
# 7                                            155320.0

# %%
X_test
# Out:
#      YEAR  Gross_Weight_Of\n_Goods_Handled\n(in thousand tonnes)  \
# 8  2018.0                                          3584537.0
# 5  2015.0                                          3343755.0
#
#    Pasangers_embarked_and_disembarkes\n(in_thousands)  \
# 8                                           411006.0
# 5                                           368222.0
#
#    Pasangers_inward\n(in thousands)  Pasangers_outward\n(in thousands)  \
# 8                          205451.0                           204047.0
# 5                          184268.0                           183111.0
#
#    ShortSeaShipping_Weight\n_of_Goods_transported\n(in thousands tonnes)  \
# 8                                          1771398.0
# 5                                          1660535.0
#
#    DeepSeaShipping_Weight_\nof_Goods_transported\n(in thousand tonnes)  \
# 8                                          1137964.0
# 5                                          1063441.0
#
#    Total_Vessels  GeneralCargo(NonSpecialised)\nvessel  Pasanger_Ship\nVessel  \
# 8      2189422.0                             1583477.0               340848.0
# 5      1991274.0                             1430425.0               314502.0
#
#    Liquid_Bulk_Tanker\nVessel  Container_Ship\nVessel  Other_Vessels\nJ-K-L  \
# 8                     83909.0                 75639.0              105549.0
# 5                     82067.0                 72050.0               92230.0
#
#    Gross_tonnage_in_thousands_by_all types_of_\nvessels\n  \
# 8                                         16173588.0
# 5                                         14280662.0
#
#    Turnover(in thousand euros)\nin Marinetime_transport_sector
# 8                                           160310.0
# 5                                           150563.0

# %%
Y_test
# Out:
# 8    30123.0
# 5    32476.0
# Name: Gross_Value_Added \n(in Thousand Euros)\nin Marinetime_transport_sector, dtype: float64

# %%
Y_train
# Out:
# 9     34244.0
# 0     30004.0
# 4     28785.0
# 3     29049.0
# 10    29509.0
# 1     27108.0
# 6     27088.0
# 2     27419.0
# 7     31032.0
# Name: Gross_Value_Added \n(in Thousand Euros)\nin Marinetime_transport_sector, dtype: float64

# %%
model=SVC(kernel='linear',gamma='auto')
model.fit(X_train,Y_train)
# Out:
# SVC(gamma='auto', kernel='linear')

# %%
Y_pred=model.predict(X_test)
Y_pred
# Out:
# array([34244., 27108.])

# %%
model.score(X_test,Y_test)
# Out:
# 0.0

# %%
model.score(X_test,Y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 model.score(X_test,Y_test)
#
# NameError: name 'model' is not defined
